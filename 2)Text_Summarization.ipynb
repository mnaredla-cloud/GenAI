# %% [markdown]
# <a href="https://colab.research.google.com/github/mnaredla-cloud/GenAI/blob/main/2)Text_Summarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##### Text_Summarization #####

#For the given text, it gives the summary

# %%
from transformers import pipeline
result = pipeline(task="summarization")
result("""Generative AI (GenAI) is revolutionizing the way we create and interact with technology. Unlike traditional AI, which analyzes and classifies existing data, GenAI goes a step further—it creates. From drafting compelling text to generating lifelike images and composing original music, GenAI mimics human creativity using powerful models trained on vast datasets.
At the heart of this transformation are tools like OpenAI’s ChatGPT for language, DALL·E for images, and Sora for videos. These models can write code, design graphics, produce marketing content, and even simulate voices. Businesses are rapidly adopting GenAI to enhance productivity, accelerate innovation, and unlock new revenue streams.
But with great power comes great responsibility""")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# [{'summary_text': ' Generative AI (GenAI) is revolutionizing the way we create and interact with technology . Unlike traditional AI, GenAI goes a step further and mimics human creativity using powerful models trained on vast datasets . Businesses are rapidly adopting GenAI to enhance productivity, accelerate innovation and unlock new revenue streams .'}]

# %%
text = """Generative AI (GenAI) is revolutionizing the way we create and interact with technology. Unlike traditional AI, which analyzes and classifies existing data, GenAI goes a step further—it creates. From drafting compelling text to generating lifelike images and composing original music, GenAI mimics human creativity using powerful models trained on vast datasets.
At the heart of this transformation are tools like OpenAI’s ChatGPT for language, DALL·E for images, and Sora for videos. These models can write code, design graphics, produce marketing content, and even simulate voices. Businesses are rapidly adopting GenAI to enhance productivity, accelerate innovation, and unlock new revenue streams.
But with great power comes great responsibility. As GenAI evolves, ethical considerations around misinformation, intellectual property, and bias are gaining importance. Ensuring transparency and responsible use is critical as we enter this new era of machine-assisted creativity.
GenAI isn’t just a tool—it’s a collaborator. It empowers individuals and organizations to think beyond limitations and create in ways previously unimaginable."""

from transformers import pipeline

summarizer = pipeline(task="summarization")

summary = summarizer(text)

print(summary)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# [{'summary_text': ' Generative AI (GenAI) is revolutionizing the way we create and interact with technology . Unlike traditional AI, GenAI goes a step further and mimics human creativity . Businesses are rapidly adopting GenAI to enhance productivity, accelerate innovation, and unlock new revenue streams . As GenAI evolves, ethical considerations around misinformation and intellectual property are gaining importance .'}]

# %%
text = """Generative AI (GenAI) is revolutionizing the way we create and interact with technology. Unlike traditional AI, which analyzes and classifies existing data, GenAI goes a step further—it creates. From drafting compelling text to generating lifelike images and composing original music, GenAI mimics human creativity using powerful models trained on vast datasets.
At the heart of this transformation are tools like OpenAI’s ChatGPT for language, DALL·E for images, and Sora for videos. These models can write code, design graphics, produce marketing content, and even simulate voices. Businesses are rapidly adopting GenAI to enhance productivity, accelerate innovation, and unlock new revenue streams.
But with great power comes great responsibility. As GenAI evolves, ethical considerations around misinformation, intellectual property, and bias are gaining importance. Ensuring transparency and responsible use is critical as we enter this new era of machine-assisted creativity.
GenAI isn’t just a tool—it’s a collaborator. It empowers individuals and organizations to think beyond limitations and create in ways previously unimaginable."""

from transformers import pipeline

summarizer = pipeline(task="summarization", min_length = 30, max_length =90) # min and max of tokens

summary = summarizer(text)

print(summary)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# [{'summary_text': ' Generative AI (GenAI) is revolutionizing the way we create and interact with technology . Unlike traditional AI, GenAI goes a step further and mimics human creativity . Businesses are rapidly adopting GenAI to enhance productivity, accelerate innovation, and unlock new revenue streams . As GenAI evolves, ethical considerations around misinformation and intellectual property are gaining importance .'}]
