# %% [markdown]
# <a href="https://colab.research.google.com/github/mnaredla-cloud/GenAI/blob/main/5)Token_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##### Token_Classification  #####

#Token Classification like names, date, locations etc..
#ner >> Named Entity Recognision
#pos >> Parts of Speech

# %%
from transformers import pipeline
result = pipeline("ner")
text="Elon Musk Founded Tesla in 2023 and spacex in 2020"
print(result(text))
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496 (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# [{'entity': 'I-PER', 'score': np.float32(0.99930084), 'index': 1, 'word': 'El', 'start': 0, 'end': 2}, {'entity': 'I-PER', 'score': np.float32(0.9987643), 'index': 2, 'word': '##on', 'start': 2, 'end': 4}, {'entity': 'I-PER', 'score': np.float32(0.9986966), 'index': 3, 'word': 'Mu', 'start': 5, 'end': 7}, {'entity': 'I-PER', 'score': np.float32(0.99302894), 'index': 4, 'word': '##sk', 'start': 7, 'end': 9}, {'entity': 'I-ORG', 'score': np.float32(0.98765635), 'index': 6, 'word': 'Te', 'start': 18, 'end': 20}, {'entity': 'I-ORG', 'score': np.float32(0.97210747), 'index': 7, 'word': '##sla', 'start': 20, 'end': 23}, {'entity': 'I-ORG', 'score': np.float32(0.75247157), 'index': 12, 'word': 'space', 'start': 36, 'end': 41}, {'entity': 'I-ORG', 'score': np.float32(0.94324565), 'index': 13, 'word': '##x', 'start': 41, 'end': 42}]

# %%
#Token Classification like names, date, locations etc..

#ner = named entity recognisation

from transformers import pipeline

ner = pipeline("ner")

text = "Elon Musk Founded Tesla in 2023 and spacex in 2020"

print(ner(text))
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496 (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# [{'entity': 'I-PER', 'score': np.float32(0.99930084), 'index': 1, 'word': 'El', 'start': 0, 'end': 2}, {'entity': 'I-PER', 'score': np.float32(0.9987643), 'index': 2, 'word': '##on', 'start': 2, 'end': 4}, {'entity': 'I-PER', 'score': np.float32(0.9986966), 'index': 3, 'word': 'Mu', 'start': 5, 'end': 7}, {'entity': 'I-PER', 'score': np.float32(0.99302894), 'index': 4, 'word': '##sk', 'start': 7, 'end': 9}, {'entity': 'I-ORG', 'score': np.float32(0.98765635), 'index': 6, 'word': 'Te', 'start': 18, 'end': 20}, {'entity': 'I-ORG', 'score': np.float32(0.97210747), 'index': 7, 'word': '##sla', 'start': 20, 'end': 23}, {'entity': 'I-ORG', 'score': np.float32(0.75247157), 'index': 12, 'word': 'space', 'start': 36, 'end': 41}, {'entity': 'I-ORG', 'score': np.float32(0.94324565), 'index': 13, 'word': '##x', 'start': 41, 'end': 42}]

# %%
#Token Classification like names, date, locations etc..

#ner = named entity recognisation

#grouped_entities >>for grouping the tokens

from transformers import pipeline

ner = pipeline("ner", grouped_entities = True)

text = "Elon Musk Founded Tesla in 2023 and spacex in 2020"

print(ner(text))
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496 (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/token_classification.py:186: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="AggregationStrategy.SIMPLE"` instead.
#   warnings.warn(
# [{'entity_group': 'PER', 'score': np.float32(0.99744767), 'word': 'Elon Musk', 'start': 0, 'end': 9}, {'entity_group': 'ORG', 'score': np.float32(0.9798819), 'word': 'Tesla', 'start': 18, 'end': 23}, {'entity_group': 'ORG', 'score': np.float32(0.8478586), 'word': 'spacex', 'start': 36, 'end': 42}]

# %%
#Token Classification like names, date, locations etc..

#directly passing the trained model

#pos  >>for parts of speech

from transformers import pipeline

ner = pipeline(model = "vblagoje/bert-english-uncased-finetuned-pos")

text = "Elon Musk Founded Tesla in 2023 and spacex in 2020"

print(ner(text))
# Out:
# Some weights of the model checkpoint at vblagoje/bert-english-uncased-finetuned-pos were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# [{'entity': 'PROPN', 'score': np.float32(0.99848), 'index': 1, 'word': 'el', 'start': 0, 'end': 2}, {'entity': 'PROPN', 'score': np.float32(0.99794585), 'index': 2, 'word': '##on', 'start': 2, 'end': 4}, {'entity': 'PROPN', 'score': np.float32(0.99866474), 'index': 3, 'word': 'mu', 'start': 5, 'end': 7}, {'entity': 'PROPN', 'score': np.float32(0.99881196), 'index': 4, 'word': '##sk', 'start': 7, 'end': 9}, {'entity': 'VERB', 'score': np.float32(0.9994473), 'index': 5, 'word': 'founded', 'start': 10, 'end': 17}, {'entity': 'PROPN', 'score': np.float32(0.99902666), 'index': 6, 'word': 'tesla', 'start': 18, 'end': 23}, {'entity': 'ADP', 'score': np.float32(0.99926585), 'index': 7, 'word': 'in', 'start': 24, 'end': 26}, {'entity': 'NUM', 'score': np.float32(0.9954881), 'index': 8, 'word': '202', 'start': 27, 'end': 30}, {'entity': 'NUM', 'score': np.float32(0.9978775), 'index': 9, 'word': '##3', 'start': 30, 'end': 31}, {'entity': 'CCONJ', 'score': np.float32(0.9988519), 'index': 10, 'word': 'and', 'start': 32, 'end': 35}, {'entity': 'PROPN', 'score': np.float32(0.9889804), 'index': 11, 'word': 'space', 'start': 36, 'end': 41}, {'entity': 'PROPN', 'score': np.float32(0.99715143), 'index': 12, 'word': '##x', 'start': 41, 'end': 42}, {'entity': 'ADP', 'score': np.float32(0.9991837), 'index': 13, 'word': 'in', 'start': 43, 'end': 45}, {'entity': 'NUM', 'score': np.float32(0.9985898), 'index': 14, 'word': '2020', 'start': 46, 'end': 50}]
