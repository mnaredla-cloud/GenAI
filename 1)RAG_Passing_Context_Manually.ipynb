# %% [markdown]
# <a href="https://colab.research.google.com/github/mnaredla-cloud/GenAI/blob/main/RAG/1)RAG_Passing_Context_Manually.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline
pipe = pipeline("text-generation", model="Qwen/Qwen2.5-1.5B-Instruct")
# Out:
# Device set to use cpu

# %%
question1 = "What is an ACE?"
question2 = "What is a volley?"

prompt = "Answer the question\n" + \
"Question:"+ question1 + "\n" + \
"Answer:"
print(prompt)
# Out:
# Answer the question
# Question:What is an ACE?
# Answer:

# %%
result = pipe(prompt, max_new_tokens = 50)
print(result)

#generated something meaningless answer...as didn't pass any context
# Out:
# [{'generated_text': 'Answer the question\nQuestion:What is an ACE?\nAnswer: An ACE is a term used to describe a person who has been sexually assaulted, physically abused, or emotionally abused. The acronym stands for "adult child of an alcoholic." These terms are often used in therapy and counseling settings as a way to acknowledge that'}]

# %%
question1 = "What is an ACE?"
question2 = "What is a volley?"

prompt = "Answer the question\n" + \
"Question: "+ question2 + "\n" + \
"Answer: "
print(prompt)
# Out:
# Answer the question
# Question: What is a volley?
# Answer:

# %%
result = pipe(prompt, max_new_tokens = 50)
print(result)
# Out:
# [{'generated_text': "Answer the question\nQuestion: What is a volley?\nAnswer:  A volleyball is a sport played by two teams of six players each. The objective is to score points by landing a ball in the opponent's court, while avoiding being hit out of bounds or over the net.\n\nBased on the information provided, which of"}]

# %%
#######Passing context manually##########

# %%
##Passing context to the First question

context = """ACE is a serve that lands in the corret service court without the receiving player touching it with their rocket, resulting in a point for the server. When a player hits an ace, they immediatly win the point, regardless of the opponent's position or attempted return. The term ace in tennis was coined by sports journalist Allison Dazing."""

# %%
question1 = "What is an ACE?"
question2 = "What is a volley?"

prompt = "Answer the question using the below context.\n" + \
"context: " + context + "\n" + \
"Question: "+ question1 + "\n" + \
"Answer: "
print(prompt)
# Out:
# Answer the question using the below context.
# context: ACE is a serve that lands in the corret service court without the receiving player touching it with their rocket, resulting in a point for the server. When a player hits an ace, they immediatly win the point, regardless of the opponent's position or attempted return. The term ace in tennis was coined by sports journalist Allison Dazing.
# Question: What is an ACE?
# Answer:

# %%
result = pipe(prompt, max_new_tokens = 50)
print(result)
# Out:
# [{'generated_text': "Answer the question using the below context.\ncontext: ACE is a serve that lands in the corret service court without the receiving player touching it with their rocket, resulting in a point for the server. When a player hits an ace, they immediatly win the point, regardless of the opponent's position or attempted return. The term ace in tennis was coined by sports journalist Allison Dazing.\nQuestion: What is an ACE?\nAnswer:  An ace in tennis is when a player hits the ball so well that it goes into the correct service area and does not hit any part of the net or the ground before it touches the receiver. It results in winning the point immediately because the receiver has"}]

# %%
##Passing context to the second question

context = """In tennis, a volly is a short where the
ball is struck before it bounces on the ground, typically performed near the net, aiming to end the point quickly or disrupt the opponents's rythm."""

# %%
question1 = "What is an ACE?"
question2 = "What is a volley?"

prompt = "Answer the question using the below context.\n" + \
"context: " + context + "\n" + \
"Question: "+ question2 + "\n" + \
"Answer: "
print(prompt)
# Out:
# Answer the question using the below context.
# context: In tennis, a volly is a short where the
# ball is struck before it bounces on the ground, typically performed near the net, aiming to end the point quickly or disrupt the opponents's rythm.
# Question: What is a volley?
# Answer:

# %%
result = pipe(prompt, max_new_tokens = 50)
print(result)
# Out:
# [{'generated_text': "Answer the question using the below context.\ncontext: In tennis, a volly is a short where the\nball is struck before it bounces on the ground, typically performed near the net, aiming to end the point quickly or disrupt the opponents's rythm.\nQuestion: What is a volley?\nAnswer:  A volley in tennis is a shot that is hit while the ball is still airborne and bouncing on the court. It involves striking the ball before it touches the ground, often done at the net to stop play or cause disruption to the opponent's rhythm."}]
