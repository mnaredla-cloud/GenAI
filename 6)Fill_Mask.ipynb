# %% [markdown]
# <a href="https://colab.research.google.com/github/mnaredla-cloud/GenAI/blob/main/6)Fill_Mask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##### Fill_Mask #####

#fill mask // for filling the blanks

# %%
#default model expects in <mask> & in lower-case

from transformers import pipeline
fill_mask = pipeline("fill-mask")
text="Texas is the Biggest <mask> in the USA"
print(fill_mask(text))
# Out:
# No model was supplied, defaulted to distilbert/distilroberta-base and revision fb53ab8 (https://huggingface.co/distilbert/distilroberta-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Some weights of the model checkpoint at distilbert/distilroberta-base were not used when initializing RobertaForMaskedLM: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# [{'score': 0.1407674103975296, 'token': 331, 'token_str': ' State', 'sequence': 'Texas is the Biggest State in the USA'}, {'score': 0.05916186794638634, 'token': 412, 'token_str': ' City', 'sequence': 'Texas is the Biggest City in the USA'}, {'score': 0.04960225522518158, 'token': 5093, 'token_str': ' Country', 'sequence': 'Texas is the Biggest Country in the USA'}, {'score': 0.020253492519259453, 'token': 3192, 'token_str': ' Land', 'sequence': 'Texas is the Biggest Land in the USA'}, {'score': 0.018805431202054024, 'token': 26283, 'token_str': ' Problem', 'sequence': 'Texas is the Biggest Problem in the USA'}]

# %%
#fill mask // for filling blank
#passing the model

from transformers import pipeline

fill_mask = pipeline("fill-mask",model = "google-bert/bert-base-uncased")

text = "Elon Musk [MASK] Tesla in 2023 and spacex in 2020"

print(fill_mask(text))
# Out:
# Some weights of the model checkpoint at google-bert/bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# [{'score': 0.23394277691841125, 'token': 1010, 'token_str': ',', 'sequence': 'elon musk, tesla in 2023 and spacex in 2020'}, {'score': 0.11904473602771759, 'token': 1998, 'token_str': 'and', 'sequence': 'elon musk and tesla in 2023 and spacex in 2020'}, {'score': 0.11019901931285858, 'token': 2587, 'token_str': 'joined', 'sequence': 'elon musk joined tesla in 2023 and spacex in 2020'}, {'score': 0.046233221888542175, 'token': 2999, 'token_str': 'replaced', 'sequence': 'elon musk replaced tesla in 2023 and spacex in 2020'}, {'score': 0.04529568552970886, 'token': 1011, 'token_str': '-', 'sequence': 'elon musk - tesla in 2023 and spacex in 2020'}]

# %%
#fill mask // for filling blank

#model name not passed

#In default model, it expects <mask>, isted of [MASK]

from transformers import pipeline

fill_mask = pipeline("fill-mask")

text = "Elon Musk <mask> Tesla in 2023 and spacex in 2020"

print(fill_mask(text))
# Out:
# No model was supplied, defaulted to distilbert/distilroberta-base and revision fb53ab8 (https://huggingface.co/distilbert/distilroberta-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Some weights of the model checkpoint at distilbert/distilroberta-base were not used when initializing RobertaForMaskedLM: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# [{'score': 0.5131831169128418, 'token': 10158, 'token_str': ' launches', 'sequence': 'Elon Musk launches Tesla in 2023 and spacex in 2020'}, {'score': 0.09939006716012955, 'token': 3247, 'token_str': ' targets', 'sequence': 'Elon Musk targets Tesla in 2023 and spacex in 2020'}, {'score': 0.04502656310796738, 'token': 3352, 'token_str': ' expects', 'sequence': 'Elon Musk expects Tesla in 2023 and spacex in 2020'}, {'score': 0.03647419437766075, 'token': 6627, 'token_str': ' launching', 'sequence': 'Elon Musk launching Tesla in 2023 and spacex in 2020'}, {'score': 0.035692255944013596, 'token': 3681, 'token_str': ' sees', 'sequence': 'Elon Musk sees Tesla in 2023 and spacex in 2020'}]
