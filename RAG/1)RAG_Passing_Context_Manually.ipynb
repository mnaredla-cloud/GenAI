# %% [markdown]
# <a href="https://colab.research.google.com/github/mnaredla-cloud/GenAI/blob/main/RAG/1)RAG_Passing_Context_Manually.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline
pipe = pipeline("text-generation", model="Qwen/Qwen2.5-1.5B-Instruct")
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu

# %%
question1 = "What is an ACE?"
question2 = "What is a volley?"

prompt = "Answer the question\n" + \
"Question:"+ question1 + "\n" + \
"Answer:"
print(prompt)
# Out:
# Answer the question
# Question:What is an ACE?
# Answer:

# %%
result = pipe(prompt, max_new_tokens = 50)
print(result)

#generated something meaningless answer...as didn't pass any context
# Out:
# [{'generated_text': 'Answer the question\nQuestion:What is an ACE?\nAnswer: An ACE is a type of engine used in various vehicles, particularly in trucks and some buses. It stands for "Auxiliary Control Engine," which refers to a smaller, more efficient engine that can be added to larger engines to improve fuel efficiency or power'}]

# %%
question1 = "What is an ACE?"
question2 = "What is a volley?"

prompt = "Answer the question\n" + \
"Question: "+ question2 + "\n" + \
"Answer: "
print(prompt)
# Out:
# Answer the question
# Question: What is a volley?
# Answer:

# %%
result = pipe(prompt, max_new_tokens = 50)
print(result)
# Out:
# [{'generated_text': 'Answer the question\nQuestion: What is a volley?\nAnswer:  A volley in tennis refers to a return shot that follows a bounce of an opponent\'s serve or point. The term "volley" derives from the word "volta", meaning turn, and was first used by the British tennis player William Beres'}]

# %%
#######Passing context manually##########

# %%
##Passing context to the First question

context = """ACE is a serve that lands in the corret service court without the receiving player touching it with their rocket, resulting in a point for the server. When a player hits an ace, they immediatly win the point, regardless of the opponent's position or attempted return. The term ace in tennis was coined by sports journalist Allison Dazing."""

# %%
question1 = "What is an ACE?"
question2 = "What is a volley?"

prompt = "Answer the question using the below context.\n" + \
"context: " + context + "\n" + \
"Question: "+ question1 + "\n" + \
"Answer: "
print(prompt)
# Out:
# Answer the question using the below context.
# context: ACE is a serve that lands in the corret service court without the receiving player touching it with their rocket, resulting in a point for the server. When a player hits an ace, they immediatly win the point, regardless of the opponent's position or attempted return. The term ace in tennis was coined by sports journalist Allison Dazing.
# Question: What is an ACE?
# Answer:

# %%
result = pipe(prompt, max_new_tokens = 50)
print(result)
# Out:
# [{'generated_text': 'Answer the question using the below context.\ncontext: ACE is a serve that lands in the corret service court without the receiving player touching it with their rocket, resulting in a point for the server. When a player hits an ace, they immediatly win the point, regardless of the opponent\'s position or attempted return. The term ace in tennis was coined by sports journalist Allison Dazing.\nQuestion: What is an ACE?\nAnswer:  An ACE is a serve in tennis where the ball lands in the correct service area and touches the ground before the receiver has a chance to hit it. It results in a point being awarded to the server. The name "ace" comes from the fact'}]

# %%
##Passing context to the second question

context = """In tennis, a volly is a short where the
ball is struck before it bounces on the ground, typically performed near the net, aiming to end the point quickly or disrupt the opponents's rythm."""

# %%
question1 = "What is an ACE?"
question2 = "What is a volley?"

prompt = "Answer the question using the below context.\n" + \
"context: " + context + "\n" + \
"Question: "+ question2 + "\n" + \
"Answer: "
print(prompt)
# Out:
# Answer the question using the below context.
# context: In tennis, a volly is a short where the
# ball is struck before it bounces on the ground, typically performed near the net, aiming to end the point quickly or disrupt the opponents's rythm.
# Question: What is a volley?
# Answer:

# %%
result = pipe(prompt, max_new_tokens = 50)
print(result)
# Out:
# [{'generated_text': "Answer the question using the below context.\ncontext: In tennis, a volly is a short where the\nball is struck before it bounces on the ground, typically performed near the net, aiming to end the point quickly or disrupt the opponents's rythm.\nQuestion: What is a volley?\nAnswer:  A volley in tennis is a short where the ball is struck before it bounces on the ground. It is typically performed near the net and aims to end the point quickly or disrupt the opponent's rhythm."}]
