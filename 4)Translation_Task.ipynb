# %% [markdown]
# <a href="https://colab.research.google.com/github/mnaredla-cloud/GenAI/blob/main/4)Translation_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##### Translation_Task #####

#Translator for converting English to French

# %%
from transformers import pipeline
result = pipeline(task="translation_en_to_fr") # From English to French
result("My name is Manohar Reddy")
# Out:
# No model was supplied, defaulted to google-t5/t5-base and revision a9723ea (https://huggingface.co/google-t5/t5-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# [{'translation_text': 'Mon nom est Manohar Reddy'}]

# %%
#Translator for converting English to French
from transformers import pipeline

translation = pipeline(task="translation_en_to_fr")

text = "My name is Manohar Reddy"

print(translation(text))
# Out:
# No model was supplied, defaulted to google-t5/t5-base and revision a9723ea (https://huggingface.co/google-t5/t5-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# [{'translation_text': 'Mon nom est Manohar Reddy'}]
