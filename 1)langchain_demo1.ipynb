# %% [markdown]
# <a href="https://colab.research.google.com/github/mnaredla-cloud/GenAI/blob/main/LangChain/1)langchain_demo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install --upgrade -q langchain langchain-community

# %%
from transformers import pipeline
from langchain_community.llms import HuggingFacePipeline

# %%
pipe = pipeline(task="text-generation", model="Qwen/Qwen2.5-1.5B-Instruct", max_length = 512)
# Out:
# Device set to use cpu

# %%
#wrap the pipeline in langchain
#HuggingFacePipeline acts as a bridge between HuggingFace and Langchain

chat_model = HuggingFacePipeline(pipeline=pipe)

# %%
response = chat_model.invoke("Explain LangChain in simple terms?")

# %%
print(response)
# Out:
# Explain LangChain in simple terms? Sure, I'd be happy to explain LangChain in simple terms!
#
# LangChain is a software framework designed for natural language processing (NLP). It's like a toolkit that helps you build NLP applications more efficiently and effectively. Think of it as Lego blocks but for AI.
#
# Here’s how it works:
#
# 1. **Building Blocks**: LangChain provides different components or "blocks" that can be combined together to create complex NLP models. These blocks are pre-built libraries that handle specific tasks such as text generation, summarization, translation, etc.
#
# 2. **Flexibility**: With LangChain, developers have the flexibility to choose which blocks they want to use based on their project needs. This makes it easy to customize your NLP application without having to start from scratch with every feature.
#
# ...
