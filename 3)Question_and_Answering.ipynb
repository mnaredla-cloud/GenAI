# %% [markdown]
# <a href="https://colab.research.google.com/github/mnaredla-cloud/GenAI/blob/main/3)Question_and_Answering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##### Question_and_Answering #####

#For the given question and context, it gives answer.

# %%
from transformers import pipeline
result = pipeline("question-answering")
context = "Hugging Face is a French company based in New-York."
question = "Where is Hugging Face based?"
result(context=context, question=question)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# {'score': 0.9711987972259521, 'start': 42, 'end': 50, 'answer': 'New-York'}

# %%
from transformers import pipeline

classifier = pipeline(task="question-answering")

text = "Hugging Face is a company and open-source community that provides tools, libraries, and models for working with machine learning (ML) and natural language processing (NLP), especially in the field of Generative AI."

qus = "What is Hugging Face?"

result = classifier(context = text, question = qus)

print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# {'score': 0.6960449814796448, 'start': 16, 'end': 51, 'answer': 'a company and open-source community'}
